# %% [markdown]
# adjacency matrix - 1 for connection, else 0
# undirected graph - symmetric adjacency matrix about diagonal, and asymmetric for directed graph O(V*V) space
# adjacency list - unordered_map<int, vector<int>> adj - {0:{1,2,3}, 1:{3,4,5}, etc.} O(V+E) space
#
# hint of graph qs:
# entities are labelled
# hinting towards relation/edges
